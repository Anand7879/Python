# %%
def print_message(msg):

    #nested function
    def printer():
        print(msg)
    printer()

print_message("Anand")
# Out:
# Anand

# %%
def print_message(msg):

    #nested function
    def printer():
        print(msg)

    return printer

another = print_message("Anand") 
another()
# Out:
# Anand
